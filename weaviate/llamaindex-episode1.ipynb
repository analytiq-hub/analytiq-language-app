# %% [markdown]
# # LlamaIndex Episode 1 🦙

# %% [markdown]
# ## Overview
#
# * What is LlamaIndex?
#
#         * LlamaHub (data loaders)
#
# * How to setup Weaviate
#
#         * Create schema
#
#
# * Adding Data to Weaviate using LlamaIndex
#
#         *  Data loader examples
#
# * Chunking up your data
#
# * Connecting Weaviate instance to LlamaIndex
#
# * Simple query engine

# %% [markdown]
# ## What is [LlamaIndex](https://www.llamaindex.ai/)?

# %% [markdown]
# #### Framework that enables you to connect LLMs and storage providers together seamlessly.
# #### LlamaIndex 🤝 Weaviate ➡ Ultimate RAG stack

# %% [markdown]
# #### [LlamaHub](https://llama-hub-ui.vercel.app/): Enables you to connect to a number of external data sources (Notion, Slack, Web pages, and more!)

# %% [markdown]
# ## Setting up Weaviate
#
# 1. Embedded
#
# 2. WCS
#
# 3. Docker

# %% [markdown]
# ### Embedded

# %%
import weaviate

# Need the latest version of the Weaviate python client (3.21)

client = weaviate.Client(embedded_options=weaviate.EmbeddedOptions())

# %% [markdown]
# ### WCS

# %%
import weaviate

client = weaviate.Client(
  url="https://llamaindex-episode1-samtusdu.weaviate.network",  # URL of your Weaviate instance
  additional_headers={
    "X-OPENAI-Api-Key": "sk-key", # Replace with your OpenAI key
  }
)

client.schema.get()  # Get the schema to test connection

# %% [markdown]
# ### Docker

# %%
import weaviate 

client = weaviate.Client("http://localhost:8081")

# %% [markdown]
# ### Schema

# %%
schema = {
   "classes": [
       {
           "class": "BlogPost",
           "description": "Blog post from the Weaviate website.",
           "vectorizer": "text2vec-openai",
           "moduleConfig": {
               "generative-openai": { 
                    "model": "gpt-3.5-turbo"
                }
           },
           "properties": [
               {
                  "name": "Content",
                  "dataType": ["text"],
                  "description": "Content from the blog post",
               }
            ]
        }
    ]
}

client.schema.delete_all()

client.schema.create(schema)

print("Schema was created.")
# Out:
# Schema was created.

# %% [markdown]
# ## Adding Data to Weaviate using LlamaIndex

# %% [markdown]
# ### SimpleDirectoryReader: Read files in your filesystem

# %%
from llama_index import SimpleDirectoryReader

blogs = SimpleDirectoryReader('../data').load_data()
# Out:
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/tools/base.py:75: ImportWarning: __package__ != __spec__.parent
#   return super().__new__(cls, name, bases, dct)
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/tools/json/tool.py:28: ImportWarning: __package__ != __spec__.parent
#   class JsonSpec(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/tools/office365/create_draft_message.py:9: ImportWarning: __package__ != __spec__.parent
#   class CreateDraftMessageSchema(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/tools/office365/events_search.py:17: ImportWarning: __package__ != __spec__.parent
#   class SearchEventsInput(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/tools/office365/messages_search.py:16: ImportWarning: __package__ != __spec__.parent
#   class SearchEmailsInput(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/tools/office365/send_event.py:16: ImportWarning: __package__ != __spec__.parent
#   class SendEventSchema(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/tools/office365/send_message.py:9: ImportWarning: __package__ != __spec__.parent
#   class SendMessageSchema(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/openapi_schema_pydantic/v3/v3_1_0/reference.py:6: ImportWarning: __package__ != __spec__.parent
#   class Reference(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/openapi_schema_pydantic/v3/v3_1_0/example.py:6: ImportWarning: __package__ != __spec__.parent
#   class Example(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/openapi_schema_pydantic/v3/v3_1_0/encoding.py:8: ImportWarning: __package__ != __spec__.parent
#   class Encoding(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/openapi_schema_pydantic/v3/v3_1_0/discriminator.py:6: ImportWarning: __package__ != __spec__.parent
#   class Discriminator(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/openapi_schema_pydantic/v3/v3_1_0/external_documentation.py:6: ImportWarning: __package__ != __spec__.parent
#   class ExternalDocumentation(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/openapi_schema_pydantic/v3/v3_1_0/xml.py:6: ImportWarning: __package__ != __spec__.parent
#   class XML(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/openapi_schema_pydantic/v3/v3_1_0/schema.py:10: ImportWarning: __package__ != __spec__.parent
#   class Schema(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/openapi_schema_pydantic/v3/v3_1_0/media_type.py:11: ImportWarning: __package__ != __spec__.parent
#   class MediaType(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/openapi_schema_pydantic/v3/v3_1_0/parameter.py:11: ImportWarning: __package__ != __spec__.parent
#   class Parameter(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/openapi_schema_pydantic/v3/v3_1_0/header.py:6: ImportWarning: __package__ != __spec__.parent
#   class Header(Parameter):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/openapi_schema_pydantic/v3/v3_1_0/server_variable.py:6: ImportWarning: __package__ != __spec__.parent
#   class ServerVariable(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/openapi_schema_pydantic/v3/v3_1_0/server.py:8: ImportWarning: __package__ != __spec__.parent
#   class Server(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/openapi_schema_pydantic/v3/v3_1_0/link.py:8: ImportWarning: __package__ != __spec__.parent
#   class Link(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/openapi_schema_pydantic/v3/v3_1_0/request_body.py:8: ImportWarning: __package__ != __spec__.parent
#   class RequestBody(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/openapi_schema_pydantic/v3/v3_1_0/response.py:11: ImportWarning: __package__ != __spec__.parent
#   class Response(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/openapi_schema_pydantic/v3/v3_1_0/operation.py:15: ImportWarning: __package__ != __spec__.parent
#   class Operation(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/openapi_schema_pydantic/v3/v3_1_0/path_item.py:11: ImportWarning: __package__ != __spec__.parent
#   class PathItem(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/openapi_schema_pydantic/v3/v3_1_0/oauth_flow.py:6: ImportWarning: __package__ != __spec__.parent
#   class OAuthFlow(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/openapi_schema_pydantic/v3/v3_1_0/oauth_flows.py:8: ImportWarning: __package__ != __spec__.parent
#   class OAuthFlows(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/openapi_schema_pydantic/v3/v3_1_0/security_scheme.py:8: ImportWarning: __package__ != __spec__.parent
#   class SecurityScheme(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/openapi_schema_pydantic/v3/v3_1_0/components.py:18: ImportWarning: __package__ != __spec__.parent
#   class Components(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/openapi_schema_pydantic/v3/v3_1_0/contact.py:6: ImportWarning: __package__ != __spec__.parent
#   class Contact(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/openapi_schema_pydantic/v3/v3_1_0/license.py:6: ImportWarning: __package__ != __spec__.parent
#   class License(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/openapi_schema_pydantic/v3/v3_1_0/info.py:9: ImportWarning: __package__ != __spec__.parent
#   class Info(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/openapi_schema_pydantic/v3/v3_1_0/tag.py:8: ImportWarning: __package__ != __spec__.parent
#   class Tag(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/openapi_schema_pydantic/v3/v3_1_0/open_api.py:16: ImportWarning: __package__ != __spec__.parent
#   class OpenAPI(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/tools/openapi/utils/api_models.py:59: ImportWarning: __package__ != __spec__.parent
#   class APIPropertyBase(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/tools/openapi/utils/api_models.py:97: ImportWarning: __package__ != __spec__.parent
#   class APIProperty(APIPropertyBase):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/tools/openapi/utils/api_models.py:221: ImportWarning: __package__ != __spec__.parent
#   class APIRequestBodyProperty(APIPropertyBase):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/tools/openapi/utils/api_models.py:338: ImportWarning: __package__ != __spec__.parent
#   class APIRequestBody(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/tools/openapi/utils/api_models.py:419: ImportWarning: __package__ != __spec__.parent
#   class APIOperation(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/tools/playwright/click.py:18: ImportWarning: __package__ != __spec__.parent
#   class ClickToolInput(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/tools/playwright/extract_hyperlinks.py:19: ImportWarning: __package__ != __spec__.parent
#   class ExtractHyperlinksToolInput(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/tools/playwright/get_elements.py:20: ImportWarning: __package__ != __spec__.parent
#   class GetElementsToolInput(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/tools/playwright/navigate.py:18: ImportWarning: __package__ != __spec__.parent
#   class NavigateToolInput(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/tools/plugin.py:17: ImportWarning: __package__ != __spec__.parent
#   class ApiConfig(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/tools/plugin.py:25: ImportWarning: __package__ != __spec__.parent
#   class AIPlugin(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/tools/plugin.py:61: ImportWarning: __package__ != __spec__.parent
#   class AIPluginToolSchema(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/prompts/base.py:97: ImportWarning: __package__ != __spec__.parent
#   class StringPromptValue(PromptValue):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/prompts/prompt.py:18: ImportWarning: __package__ != __spec__.parent
#   class PromptTemplate(StringPromptTemplate):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/prompts/chat.py:84: ImportWarning: __package__ != __spec__.parent
#   class MessagesPlaceholder(BaseMessagePromptTemplate):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/prompts/chat.py:129: ImportWarning: __package__ != __spec__.parent
#   class BaseStringMessagePromptTemplate(BaseMessagePromptTemplate, ABC):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/prompts/chat.py:210: ImportWarning: __package__ != __spec__.parent
#   class ChatMessagePromptTemplate(BaseStringMessagePromptTemplate):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/prompts/chat.py:281: ImportWarning: __package__ != __spec__.parent
#   class ChatPromptValue(PromptValue):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/prompts/chat.py:341: ImportWarning: __package__ != __spec__.parent
#   class ChatPromptTemplate(BaseChatPromptTemplate, ABC):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/prompts/example_selector/length_based.py:15: ImportWarning: __package__ != __spec__.parent
#   class LengthBasedExampleSelector(BaseExampleSelector, BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/prompts/example_selector/ngram_overlap.py:41: ImportWarning: __package__ != __spec__.parent
#   class NGramOverlapExampleSelector(BaseExampleSelector, BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/embeddings/aleph_alpha.py:9: ImportWarning: __package__ != __spec__.parent
#   class AlephAlphaAsymmetricSemanticEmbedding(BaseModel, Embeddings):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/embeddings/awa.py:8: ImportWarning: __package__ != __spec__.parent
#   class AwaEmbeddings(BaseModel, Embeddings):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/embeddings/bedrock.py:12: ImportWarning: __package__ != __spec__.parent
#   class BedrockEmbeddings(BaseModel, Embeddings):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/embeddings/clarifai.py:12: ImportWarning: __package__ != __spec__.parent
#   class ClarifaiEmbeddings(BaseModel, Embeddings):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/embeddings/cohere.py:9: ImportWarning: __package__ != __spec__.parent
#   class CohereEmbeddings(BaseModel, Embeddings):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/embeddings/dashscope.py:66: ImportWarning: __package__ != __spec__.parent
#   class DashScopeEmbeddings(BaseModel, Embeddings):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/embeddings/deepinfra.py:12: ImportWarning: __package__ != __spec__.parent
#   class DeepInfraEmbeddings(BaseModel, Embeddings):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/embeddings/edenai.py:10: ImportWarning: __package__ != __spec__.parent
#   class EdenAiEmbeddings(BaseModel, Embeddings):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/embeddings/embaas.py:23: ImportWarning: __package__ != __spec__.parent
#   class EmbaasEmbeddings(BaseModel, Embeddings):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/embeddings/fake.py:10: ImportWarning: __package__ != __spec__.parent
#   class FakeEmbeddings(Embeddings, BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/embeddings/fake.py:26: ImportWarning: __package__ != __spec__.parent
#   class DeterministicFakeEmbedding(Embeddings, BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/embeddings/google_palm.py:56: ImportWarning: __package__ != __spec__.parent
#   class GooglePalmEmbeddings(BaseModel, Embeddings):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/embeddings/gpt4all.py:8: ImportWarning: __package__ != __spec__.parent
#   class GPT4AllEmbeddings(BaseModel, Embeddings):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/embeddings/huggingface.py:20: ImportWarning: __package__ != __spec__.parent
#   class HuggingFaceEmbeddings(BaseModel, Embeddings):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/embeddings/huggingface.py:107: ImportWarning: __package__ != __spec__.parent
#   class HuggingFaceInstructEmbeddings(BaseModel, Embeddings):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/embeddings/huggingface.py:187: ImportWarning: __package__ != __spec__.parent
#   class HuggingFaceBgeEmbeddings(BaseModel, Embeddings):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/embeddings/huggingface_hub.py:12: ImportWarning: __package__ != __spec__.parent
#   class HuggingFaceHubEmbeddings(BaseModel, Embeddings):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/embeddings/jina.py:11: ImportWarning: __package__ != __spec__.parent
#   class JinaEmbeddings(BaseModel, Embeddings):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/embeddings/llamacpp.py:8: ImportWarning: __package__ != __spec__.parent
#   class LlamaCppEmbeddings(BaseModel, Embeddings):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/embeddings/localai.py:120: ImportWarning: __package__ != __spec__.parent
#   class LocalAIEmbeddings(BaseModel, Embeddings):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/embeddings/minimax.py:48: ImportWarning: __package__ != __spec__.parent
#   class MiniMaxEmbeddings(BaseModel, Embeddings):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/embeddings/mlflow_gateway.py:15: ImportWarning: __package__ != __spec__.parent
#   class MlflowAIGatewayEmbeddings(Embeddings, BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/embeddings/modelscope_hub.py:8: ImportWarning: __package__ != __spec__.parent
#   class ModelScopeEmbeddings(BaseModel, Embeddings):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/embeddings/mosaicml.py:10: ImportWarning: __package__ != __spec__.parent
#   class MosaicMLInstructorEmbeddings(BaseModel, Embeddings):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/embeddings/nlpcloud.py:9: ImportWarning: __package__ != __spec__.parent
#   class NLPCloudEmbeddings(BaseModel, Embeddings):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/embeddings/octoai_embeddings.py:12: ImportWarning: __package__ != __spec__.parent
#   class OctoAIEmbeddings(BaseModel, Embeddings):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/embeddings/openai.py:121: ImportWarning: __package__ != __spec__.parent
#   class OpenAIEmbeddings(BaseModel, Embeddings):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/base.py:157: ImportWarning: __package__ != __spec__.parent
#   class BaseLLM(BaseLanguageModel[str], ABC):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/ai21.py:11: ImportWarning: __package__ != __spec__.parent
#   class AI21PenaltyData(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/ai21.py:22: ImportWarning: __package__ != __spec__.parent
#   class AI21(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/aleph_alpha.py:11: ImportWarning: __package__ != __spec__.parent
#   class AlephAlpha(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/amazon_api_gateway.py:29: ImportWarning: __package__ != __spec__.parent
#   class AmazonAPIGateway(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/anthropic.py:22: ImportWarning: __package__ != __spec__.parent
#   class _AnthropicCommon(BaseLanguageModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/anyscale.py:12: ImportWarning: __package__ != __spec__.parent
#   class Anyscale(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/aviary.py:85: ImportWarning: __package__ != __spec__.parent
#   class Aviary(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/azureml_endpoint.py:201: ImportWarning: __package__ != __spec__.parent
#   class AzureMLOnlineEndpoint(LLM, BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/bananadev.py:14: ImportWarning: __package__ != __spec__.parent
#   class Banana(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/baseten.py:12: ImportWarning: __package__ != __spec__.parent
#   class Baseten(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/beam.py:22: ImportWarning: __package__ != __spec__.parent
#   class Beam(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/bedrock.py:51: ImportWarning: __package__ != __spec__.parent
#   class Bedrock(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/bittensor.py:10: ImportWarning: __package__ != __spec__.parent
#   class NIBittensorLLM(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/cerebriumai.py:14: ImportWarning: __package__ != __spec__.parent
#   class CerebriumAI(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/chatglm.py:13: ImportWarning: __package__ != __spec__.parent
#   class ChatGLM(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/clarifai.py:14: ImportWarning: __package__ != __spec__.parent
#   class Clarifai(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/cohere.py:64: ImportWarning: __package__ != __spec__.parent
#   class Cohere(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/ctransformers.py:13: ImportWarning: __package__ != __spec__.parent
#   class CTransformers(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/databricks.py:14: ImportWarning: __package__ != __spec__.parent
#   class _DatabricksClientBase(BaseModel, ABC):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/databricks.py:33: ImportWarning: __package__ != __spec__.parent
#   class _DatabricksServingEndpointClient(_DatabricksClientBase):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/databricks.py:58: ImportWarning: __package__ != __spec__.parent
#   class _DatabricksClusterDriverProxyClient(_DatabricksClientBase):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/databricks.py:132: ImportWarning: __package__ != __spec__.parent
#   class Databricks(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/deepinfra.py:14: ImportWarning: __package__ != __spec__.parent
#   class DeepInfra(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/deepsparse.py:11: ImportWarning: __package__ != __spec__.parent
#   class DeepSparse(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/edenai.py:20: ImportWarning: __package__ != __spec__.parent
#   class EdenAI(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/fake.py:12: ImportWarning: __package__ != __spec__.parent
#   class FakeListLLM(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/fireworks.py:28: ImportWarning: __package__ != __spec__.parent
#   class BaseFireworks(BaseLLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/fireworks.py:166: ImportWarning: __package__ != __spec__.parent
#   class FireworksChat(BaseLLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/forefrontai.py:12: ImportWarning: __package__ != __spec__.parent
#   class ForefrontAI(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/google_palm.py:75: ImportWarning: __package__ != __spec__.parent
#   class GooglePalm(BaseLLM, BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/gooseai.py:13: ImportWarning: __package__ != __spec__.parent
#   class GooseAI(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/gpt4all.py:11: ImportWarning: __package__ != __spec__.parent
#   class GPT4All(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/huggingface_endpoint.py:14: ImportWarning: __package__ != __spec__.parent
#   class HuggingFaceEndpoint(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/huggingface_hub.py:14: ImportWarning: __package__ != __spec__.parent
#   class HuggingFaceHub(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/huggingface_pipeline.py:18: ImportWarning: __package__ != __spec__.parent
#   class HuggingFacePipeline(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/huggingface_text_gen_inference.py:13: ImportWarning: __package__ != __spec__.parent
#   class HuggingFaceTextGenInference(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/human.py:35: ImportWarning: __package__ != __spec__.parent
#   class HumanInputLLM(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/koboldai.py:22: ImportWarning: __package__ != __spec__.parent
#   class KoboldApiLLM(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/llamacpp.py:15: ImportWarning: __package__ != __spec__.parent
#   class LlamaCpp(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/manifest.py:9: ImportWarning: __package__ != __spec__.parent
#   class ManifestWrapper(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/minimax.py:24: ImportWarning: __package__ != __spec__.parent
#   class _MinimaxEndpointClient(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/minimax.py:55: ImportWarning: __package__ != __spec__.parent
#   class Minimax(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/mlflow_ai_gateway.py:13: ImportWarning: __package__ != __spec__.parent
#   class Params(BaseModel, extra=Extra.allow):  # type: ignore[call-arg]
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/mlflow_ai_gateway.py:23: ImportWarning: __package__ != __spec__.parent
#   class MlflowAIGateway(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/modal.py:14: ImportWarning: __package__ != __spec__.parent
#   class Modal(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/mosaicml.py:29: ImportWarning: __package__ != __spec__.parent
#   class MosaicML(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/nlpcloud.py:10: ImportWarning: __package__ != __spec__.parent
#   class NLPCloud(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/octoai_endpoint.py:11: ImportWarning: __package__ != __spec__.parent
#   class OctoAIEndpoint(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/ollama.py:25: ImportWarning: __package__ != __spec__.parent
#   class _OllamaCommon(BaseLanguageModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/openai.py:135: ImportWarning: __package__ != __spec__.parent
#   class BaseOpenAI(BaseLLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/openai.py:637: ImportWarning: __package__ != __spec__.parent
#   class AzureOpenAI(BaseOpenAI):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/openai.py:692: ImportWarning: __package__ != __spec__.parent
#   class OpenAIChat(BaseLLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/openllm.py:47: ImportWarning: __package__ != __spec__.parent
#   class OpenLLM(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/petals.py:14: ImportWarning: __package__ != __spec__.parent
#   class Petals(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/pipelineai.py:14: ImportWarning: __package__ != __spec__.parent
#   class PipelineAI(LLM, BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/predibase.py:9: ImportWarning: __package__ != __spec__.parent
#   class Predibase(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/predictionguard.py:14: ImportWarning: __package__ != __spec__.parent
#   class PredictionGuard(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/promptlayer_openai.py:12: ImportWarning: __package__ != __spec__.parent
#   class PromptLayerOpenAI(OpenAI):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/promptlayer_openai.py:121: ImportWarning: __package__ != __spec__.parent
#   class PromptLayerOpenAIChat(OpenAIChat):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/replicate.py:13: ImportWarning: __package__ != __spec__.parent
#   class Replicate(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/rwkv.py:15: ImportWarning: __package__ != __spec__.parent
#   class RWKV(LLM, BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/sagemaker_endpoint.py:65: ImportWarning: __package__ != __spec__.parent
#   class SagemakerEndpoint(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/self_hosted.py:64: ImportWarning: __package__ != __spec__.parent
#   class SelfHostedPipeline(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/self_hosted_hugging_face.py:113: ImportWarning: __package__ != __spec__.parent
#   class SelfHostedHuggingFaceLLM(SelfHostedPipeline):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/stochasticai.py:16: ImportWarning: __package__ != __spec__.parent
#   class StochasticAI(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/symblai_nebula.py:27: ImportWarning: __package__ != __spec__.parent
#   class Nebula(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/textgen.py:13: ImportWarning: __package__ != __spec__.parent
#   class TextGen(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/titan_takeoff.py:12: ImportWarning: __package__ != __spec__.parent
#   class TitanTakeoff(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/tongyi.py:87: ImportWarning: __package__ != __spec__.parent
#   class Tongyi(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/vertexai.py:61: ImportWarning: __package__ != __spec__.parent
#   class _VertexAICommon(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/vertexai.py:148: ImportWarning: __package__ != __spec__.parent
#   class VertexAI(_VertexAICommon, LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/vllm.py:11: ImportWarning: __package__ != __spec__.parent
#   class VLLM(BaseLLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/writer.py:12: ImportWarning: __package__ != __spec__.parent
#   class Writer(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/llms/xinference.py:11: ImportWarning: __package__ != __spec__.parent
#   class Xinference(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/embeddings/sagemaker_endpoint.py:13: ImportWarning: __package__ != __spec__.parent
#   class SagemakerEndpointEmbeddings(BaseModel, Embeddings):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/embeddings/self_hosted.py:18: ImportWarning: __package__ != __spec__.parent
#   class SelfHostedEmbeddings(SelfHostedPipeline, Embeddings):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/embeddings/self_hosted_hugging_face.py:59: ImportWarning: __package__ != __spec__.parent
#   class SelfHostedHuggingFaceEmbeddings(SelfHostedEmbeddings):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/embeddings/self_hosted_hugging_face.py:102: ImportWarning: __package__ != __spec__.parent
#   class SelfHostedHuggingFaceInstructEmbeddings(SelfHostedHuggingFaceEmbeddings):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/embeddings/spacy_embeddings.py:9: ImportWarning: __package__ != __spec__.parent
#   class SpacyEmbeddings(BaseModel, Embeddings):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/embeddings/tensorflow_hub.py:10: ImportWarning: __package__ != __spec__.parent
#   class TensorflowHubEmbeddings(BaseModel, Embeddings):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/embeddings/vertexai.py:10: ImportWarning: __package__ != __spec__.parent
#   class VertexAIEmbeddings(_VertexAICommon, Embeddings):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/vectorstores/base.py:523: ImportWarning: __package__ != __spec__.parent
#   class VectorStoreRetriever(BaseRetriever):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/vectorstores/azuresearch.py:528: ImportWarning: __package__ != __spec__.parent
#   class AzureSearchVectorStoreRetriever(BaseRetriever):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/vectorstores/clickhouse.py:36: ImportWarning: __package__ != __spec__.parent
#   class ClickhouseSettings(BaseSettings):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/vectorstores/myscale.py:35: ImportWarning: __package__ != __spec__.parent
#   class MyScaleSettings(BaseSettings):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/vectorstores/redis.py:614: ImportWarning: __package__ != __spec__.parent
#   class RedisVectorStoreRetriever(VectorStoreRetriever):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/vectorstores/singlestoredb.py:453: ImportWarning: __package__ != __spec__.parent
#   class SingleStoreDBRetriever(VectorStoreRetriever):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/vectorstores/starrocks.py:72: ImportWarning: __package__ != __spec__.parent
#   class StarRocksSettings(BaseSettings):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/vectorstores/vectara.py:422: ImportWarning: __package__ != __spec__.parent
#   class VectaraRetriever(VectorStoreRetriever):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/prompts/example_selector/semantic_similarity.py:18: ImportWarning: __package__ != __spec__.parent
#   class SemanticSimilarityExampleSelector(BaseExampleSelector, BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/prompts/example_selector/semantic_similarity.py:102: ImportWarning: __package__ != __spec__.parent
#   class MaxMarginalRelevanceExampleSelector(SemanticSimilarityExampleSelector):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/prompts/few_shot.py:19: ImportWarning: __package__ != __spec__.parent
#   class _FewShotPromptTemplateMixin(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/prompts/few_shot.py:72: ImportWarning: __package__ != __spec__.parent
#   class FewShotPromptTemplate(_FewShotPromptTemplateMixin, StringPromptTemplate):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/prompts/few_shot.py:166: ImportWarning: __package__ != __spec__.parent
#   class FewShotChatMessagePromptTemplate(
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/prompts/few_shot_with_templates.py:11: ImportWarning: __package__ != __spec__.parent
#   class FewShotPromptWithTemplates(StringPromptTemplate):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/output_parsers/boolean.py:4: ImportWarning: __package__ != __spec__.parent
#   class BooleanOutputParser(BaseOutputParser[bool]):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/output_parsers/combining.py:10: ImportWarning: __package__ != __spec__.parent
#   class CombiningOutputParser(BaseOutputParser):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/output_parsers/datetime.py:32: ImportWarning: __package__ != __spec__.parent
#   class DatetimeOutputParser(BaseOutputParser[datetime]):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/output_parsers/enum.py:9: ImportWarning: __package__ != __spec__.parent
#   class EnumOutputParser(BaseOutputParser):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chains/base.py:36: ImportWarning: __package__ != __spec__.parent
#   class Chain(Serializable, Runnable[Dict[str, Any], Dict[str, Any]], ABC):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chains/llm.py:30: ImportWarning: __package__ != __spec__.parent
#   class LLMChain(Chain):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/output_parsers/fix.py:13: ImportWarning: __package__ != __spec__.parent
#   class OutputFixingParser(BaseOutputParser[T]):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/output_parsers/pydantic.py:13: ImportWarning: __package__ != __spec__.parent
#   class PydanticOutputParser(BaseOutputParser[T]):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/output_parsers/rail_parser.py:8: ImportWarning: __package__ != __spec__.parent
#   class GuardrailsOutputParser(BaseOutputParser):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/output_parsers/regex.py:9: ImportWarning: __package__ != __spec__.parent
#   class RegexParser(BaseOutputParser):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/output_parsers/regex_dict.py:9: ImportWarning: __package__ != __spec__.parent
#   class RegexDictParser(BaseOutputParser):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/output_parsers/retry.py:40: ImportWarning: __package__ != __spec__.parent
#   class RetryOutputParser(BaseOutputParser[T]):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/output_parsers/retry.py:115: ImportWarning: __package__ != __spec__.parent
#   class RetryWithErrorOutputParser(BaseOutputParser[T]):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/output_parsers/structured.py:17: ImportWarning: __package__ != __spec__.parent
#   class ResponseSchema(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/output_parsers/structured.py:34: ImportWarning: __package__ != __spec__.parent
#   class StructuredOutputParser(BaseOutputParser):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/prompts/pipeline.py:13: ImportWarning: __package__ != __spec__.parent
#   class PipelinePromptTemplate(BasePromptTemplate):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chains/api/base.py:20: ImportWarning: __package__ != __spec__.parent
#   class APIChain(Chain):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chains/api/openapi/chain.py:28: ImportWarning: __package__ != __spec__.parent
#   class OpenAPIEndpointChain(Chain, BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chains/combine_documents/base.py:17: ImportWarning: __package__ != __spec__.parent
#   class BaseCombineDocumentsChain(Chain, ABC):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chains/combine_documents/base.py:129: ImportWarning: __package__ != __spec__.parent
#   class AnalyzeDocumentChain(Chain):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chains/combine_documents/reduce.py:80: ImportWarning: __package__ != __spec__.parent
#   class ReduceDocumentsChain(BaseCombineDocumentsChain):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chains/combine_documents/map_reduce.py:16: ImportWarning: __package__ != __spec__.parent
#   class MapReduceDocumentsChain(BaseCombineDocumentsChain):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chains/combine_documents/map_rerank.py:16: ImportWarning: __package__ != __spec__.parent
#   class MapRerankDocumentsChain(BaseCombineDocumentsChain):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chains/combine_documents/refine.py:23: ImportWarning: __package__ != __spec__.parent
#   class RefineDocumentsChain(BaseCombineDocumentsChain):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chains/combine_documents/stuff.py:21: ImportWarning: __package__ != __spec__.parent
#   class StuffDocumentsChain(BaseCombineDocumentsChain):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chains/constitutional_ai/models.py:5: ImportWarning: __package__ != __spec__.parent
#   class ConstitutionalPrinciple(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chains/constitutional_ai/base.py:14: ImportWarning: __package__ != __spec__.parent
#   class ConstitutionalChain(Chain):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/memory/chat_message_histories/in_memory.py:11: ImportWarning: __package__ != __spec__.parent
#   class ChatMessageHistory(BaseChatMessageHistory, BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/memory/chat_memory.py:11: ImportWarning: __package__ != __spec__.parent
#   class BaseChatMemory(BaseMemory, ABC):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/memory/buffer.py:10: ImportWarning: __package__ != __spec__.parent
#   class ConversationBufferMemory(BaseChatMemory):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/memory/buffer.py:49: ImportWarning: __package__ != __spec__.parent
#   class ConversationStringBufferMemory(BaseMemory):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/memory/buffer_window.py:7: ImportWarning: __package__ != __spec__.parent
#   class ConversationBufferWindowMemory(BaseChatMemory):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/memory/combined.py:10: ImportWarning: __package__ != __spec__.parent
#   class CombinedMemory(BaseMemory):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/memory/entity.py:52: ImportWarning: __package__ != __spec__.parent
#   class InMemoryEntityStore(BaseEntityStore):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/memory/entity.py:73: ImportWarning: __package__ != __spec__.parent
#   class RedisEntityStore(BaseEntityStore):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/memory/entity.py:156: ImportWarning: __package__ != __spec__.parent
#   class SQLiteEntityStore(BaseEntityStore):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/memory/entity.py:248: ImportWarning: __package__ != __spec__.parent
#   class ConversationEntityMemory(BaseChatMemory):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/memory/kg.py:19: ImportWarning: __package__ != __spec__.parent
#   class ConversationKGMemory(BaseChatMemory):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/memory/motorhead_memory.py:12: ImportWarning: __package__ != __spec__.parent
#   class MotorheadMemory(BaseChatMemory):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/memory/readonly.py:6: ImportWarning: __package__ != __spec__.parent
#   class ReadOnlySharedMemory(BaseMemory):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/memory/simple.py:6: ImportWarning: __package__ != __spec__.parent
#   class SimpleMemory(BaseMemory):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/memory/summary.py:18: ImportWarning: __package__ != __spec__.parent
#   class SummarizerMixin(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/memory/summary.py:40: ImportWarning: __package__ != __spec__.parent
#   class ConversationSummaryMemory(BaseChatMemory, SummarizerMixin):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/memory/summary_buffer.py:10: ImportWarning: __package__ != __spec__.parent
#   class ConversationSummaryBufferMemory(BaseChatMemory, SummarizerMixin):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/memory/token_buffer.py:8: ImportWarning: __package__ != __spec__.parent
#   class ConversationTokenBufferMemory(BaseChatMemory):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/memory/vectorstore.py:13: ImportWarning: __package__ != __spec__.parent
#   class VectorStoreRetrieverMemory(BaseMemory):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/memory/zep_memory.py:9: ImportWarning: __package__ != __spec__.parent
#   class ZepMemory(ConversationBufferMemory):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chains/conversation/base.py:12: ImportWarning: __package__ != __spec__.parent
#   class ConversationChain(LLMChain):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chat_models/base.py:53: ImportWarning: __package__ != __spec__.parent
#   class BaseChatModel(BaseLanguageModel[BaseMessageChunk], ABC):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chat_models/openai.py:120: ImportWarning: __package__ != __spec__.parent
#   class ChatOpenAI(BaseChatModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chat_models/anyscale.py:30: ImportWarning: __package__ != __spec__.parent
#   class ChatAnyscale(ChatOpenAI):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chat_models/azure_openai.py:16: ImportWarning: __package__ != __spec__.parent
#   class AzureChatOpenAI(ChatOpenAI):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chat_models/ernie.py:35: ImportWarning: __package__ != __spec__.parent
#   class ErnieBotChat(BaseChatModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chat_models/fake.py:13: ImportWarning: __package__ != __spec__.parent
#   class FakeListChatModel(SimpleChatModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chat_models/google_palm.py:216: ImportWarning: __package__ != __spec__.parent
#   class ChatGooglePalm(BaseChatModel, BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chat_models/human.py:69: ImportWarning: __package__ != __spec__.parent
#   class HumanInputChatModel(BaseChatModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chat_models/jinachat.py:142: ImportWarning: __package__ != __spec__.parent
#   class JinaChat(BaseChatModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chat_models/litellm.py:67: ImportWarning: __package__ != __spec__.parent
#   class FunctionMessage(BaseMessage):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chat_models/litellm.py:191: ImportWarning: __package__ != __spec__.parent
#   class ChatLiteLLM(BaseChatModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chat_models/mlflow_ai_gateway.py:31: ImportWarning: __package__ != __spec__.parent
#   class ChatParams(BaseModel, extra=Extra.allow):  # type: ignore[call-arg]
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chat_models/mlflow_ai_gateway.py:41: ImportWarning: __package__ != __spec__.parent
#   class ChatMLflowAIGateway(BaseChatModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chat_models/promptlayer_openai.py:14: ImportWarning: __package__ != __spec__.parent
#   class PromptLayerChatOpenAI(ChatOpenAI):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chat_models/vertexai.py:95: ImportWarning: __package__ != __spec__.parent
#   class ChatVertexAI(_VertexAICommon, BaseChatModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chains/prompt_selector.py:20: ImportWarning: __package__ != __spec__.parent
#   class ConditionalPromptSelector(BasePromptSelector):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chains/conversational_retrieval/base.py:54: ImportWarning: __package__ != __spec__.parent
#   class BaseConversationalRetrievalChain(Chain):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chains/conversational_retrieval/base.py:206: ImportWarning: __package__ != __spec__.parent
#   class ConversationalRetrievalChain(BaseConversationalRetrievalChain):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chains/conversational_retrieval/base.py:366: ImportWarning: __package__ != __spec__.parent
#   class ChatVectorDBChain(BaseConversationalRetrievalChain):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chains/flare/prompts.py:7: ImportWarning: __package__ != __spec__.parent
#   class FinishedOutputParser(BaseOutputParser[Tuple[str, bool]]):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chains/flare/base.py:25: ImportWarning: __package__ != __spec__.parent
#   class _ResponseChain(LLMChain):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chains/flare/base.py:50: ImportWarning: __package__ != __spec__.parent
#   class _OpenAIResponseChain(_ResponseChain):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chains/flare/base.py:72: ImportWarning: __package__ != __spec__.parent
#   class QuestionGeneratorChain(LLMChain):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chains/flare/base.py:105: ImportWarning: __package__ != __spec__.parent
#   class FlareChain(Chain):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chains/graph_qa/arangodb.py:22: ImportWarning: __package__ != __spec__.parent
#   class ArangoGraphQAChain(Chain):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chains/graph_qa/base.py:17: ImportWarning: __package__ != __spec__.parent
#   class GraphQAChain(Chain):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chains/graph_qa/cypher.py:38: ImportWarning: __package__ != __spec__.parent
#   class GraphCypherQAChain(Chain):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chains/graph_qa/hugegraph.py:20: ImportWarning: __package__ != __spec__.parent
#   class HugeGraphQAChain(Chain):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chains/graph_qa/kuzu.py:17: ImportWarning: __package__ != __spec__.parent
#   class KuzuQAChain(Chain):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chains/graph_qa/nebulagraph.py:17: ImportWarning: __package__ != __spec__.parent
#   class NebulaGraphQAChain(Chain):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chains/graph_qa/neptune_cypher.py:33: ImportWarning: __package__ != __spec__.parent
#   class NeptuneOpenCypherQAChain(Chain):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chains/graph_qa/sparql.py:24: ImportWarning: __package__ != __spec__.parent
#   class GraphSparqlQAChain(Chain):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chains/hyde/base.py:20: ImportWarning: __package__ != __spec__.parent
#   class HypotheticalDocumentEmbedder(Chain, Embeddings):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chains/llm_bash/base.py:21: ImportWarning: __package__ != __spec__.parent
#   class LLMBashChain(Chain):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/chains/sequential.py:14: ImportWarning: __package__ != __spec__.parent
#   class SequentialChain(Chain):
# ...
#   class JiraToolkit(BaseToolkit):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/agents/agent_toolkits/json/toolkit.py:10: ImportWarning: __package__ != __spec__.parent
#   class JsonToolkit(BaseToolkit):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/tools/multion/create_session.py:19: ImportWarning: __package__ != __spec__.parent
#   class CreateSessionSchema(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/tools/multion/update_session.py:19: ImportWarning: __package__ != __spec__.parent
#   class UpdateSessionSchema(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/agents/agent_toolkits/nla/toolkit.py:16: ImportWarning: __package__ != __spec__.parent
#   class NLAToolkit(BaseToolkit):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/agents/agent_toolkits/office365/toolkit.py:20: ImportWarning: __package__ != __spec__.parent
#   class O365Toolkit(BaseToolkit):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/agents/agent_toolkits/openapi/toolkit.py:25: ImportWarning: __package__ != __spec__.parent
#   class RequestsToolkit(BaseToolkit):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/agents/agent_toolkits/openapi/toolkit.py:41: ImportWarning: __package__ != __spec__.parent
#   class OpenAPIToolkit(BaseToolkit):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/agents/agent_toolkits/playwright/toolkit.py:34: ImportWarning: __package__ != __spec__.parent
#   class PlayWrightBrowserToolkit(BaseToolkit):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/agents/agent_toolkits/powerbi/toolkit.py:31: ImportWarning: __package__ != __spec__.parent
#   class PowerBIToolkit(BaseToolkit):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/agents/agent_toolkits/spark_sql/toolkit.py:18: ImportWarning: __package__ != __spec__.parent
#   class SparkSQLToolkit(BaseToolkit):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/agents/agent_toolkits/sql/toolkit.py:18: ImportWarning: __package__ != __spec__.parent
#   class SQLDatabaseToolkit(BaseToolkit):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/agents/agent_toolkits/vectorstore/toolkit.py:17: ImportWarning: __package__ != __spec__.parent
#   class VectorStoreInfo(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/agents/agent_toolkits/vectorstore/toolkit.py:30: ImportWarning: __package__ != __spec__.parent
#   class VectorStoreToolkit(BaseToolkit):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/agents/agent_toolkits/vectorstore/toolkit.py:64: ImportWarning: __package__ != __spec__.parent
#   class VectorStoreRouterToolkit(BaseToolkit):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/agents/agent_toolkits/zapier/toolkit.py:10: ImportWarning: __package__ != __spec__.parent
#   class ZapierToolkit(BaseToolkit):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/utilities/dalle_image_generator.py:9: ImportWarning: __package__ != __spec__.parent
#   class DallEAPIWrapper(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/utilities/dataforseo_api_search.py:12: ImportWarning: __package__ != __spec__.parent
#   class DataForSeoAPIWrapper(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/langchain/agents/xml/base.py:35: ImportWarning: __package__ != __spec__.parent
#   class XMLAgent(BaseSingleActionAgent):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/schema.py:49: ImportWarning: __package__ != __spec__.parent
#   class RelatedNodeInfo(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/schema.py:62: ImportWarning: __package__ != __spec__.parent
#   class BaseNode(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/schema.py:215: ImportWarning: __package__ != __spec__.parent
#   class TextNode(BaseNode):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/schema.py:312: ImportWarning: __package__ != __spec__.parent
#   class ImageNode(TextNode):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/schema.py:324: ImportWarning: __package__ != __spec__.parent
#   class IndexNode(TextNode):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/schema.py:334: ImportWarning: __package__ != __spec__.parent
#   class NodeWithScore(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/schema.py:342: ImportWarning: __package__ != __spec__.parent
#   class Document(TextNode):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/schema.py:396: ImportWarning: __package__ != __spec__.parent
#   class ImageDocument(Document):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/embeddings/base.py:52: ImportWarning: __package__ != __spec__.parent
#   class BaseEmbedding(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/llms/base.py:23: ImportWarning: __package__ != __spec__.parent
#   class ChatMessage(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/llms/base.py:35: ImportWarning: __package__ != __spec__.parent
#   class ChatResponse(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/llms/base.py:51: ImportWarning: __package__ != __spec__.parent
#   class CompletionResponse(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/llms/base.py:67: ImportWarning: __package__ != __spec__.parent
#   class LLMMetadata(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/llms/base.py:312: ImportWarning: __package__ != __spec__.parent
#   class LLM(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/llms/anthropic.py:31: ImportWarning: __package__ != __spec__.parent
#   class Anthropic(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/llms/openai.py:40: ImportWarning: __package__ != __spec__.parent
#   class OpenAI(LLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/llms/azure_openai.py:8: ImportWarning: __package__ != __spec__.parent
#   class AzureOpenAI(OpenAI):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/llms/huggingface.py:18: ImportWarning: __package__ != __spec__.parent
#   class HuggingFaceLLM(CustomLLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/llms/llama_cpp.py:34: ImportWarning: __package__ != __spec__.parent
#   class LlamaCPP(CustomLLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/llms/mock.py:13: ImportWarning: __package__ != __spec__.parent
#   class MockLLM(CustomLLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/llms/palm.py:16: ImportWarning: __package__ != __spec__.parent
#   class PaLM(CustomLLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/llms/predibase.py:16: ImportWarning: __package__ != __spec__.parent
#   class PredibaseLLM(CustomLLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/llms/replicate.py:24: ImportWarning: __package__ != __spec__.parent
#   class Replicate(CustomLLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/llms/xinference.py:27: ImportWarning: __package__ != __spec__.parent
#   class Xinference(CustomLLM):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/embeddings/openai.py:210: ImportWarning: __package__ != __spec__.parent
#   class OpenAIEmbedding(BaseEmbedding):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/token_counter/mock_embed_model.py:8: ImportWarning: __package__ != __spec__.parent
#   class MockEmbedding(BaseEmbedding):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/memory/chat_memory_buffer.py:13: ImportWarning: __package__ != __spec__.parent
#   class ChatMemoryBuffer(BaseMemory):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/langchain_helpers/agents/tools.py:30: ImportWarning: __package__ != __spec__.parent
#   class IndexToolConfig(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/langchain_helpers/agents/toolkits.py:14: ImportWarning: __package__ != __spec__.parent
#   class LlamaToolkit(BaseToolkit):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/tools/types.py:9: ImportWarning: __package__ != __spec__.parent
#   class DefaultToolFnSchema(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/tools/types.py:54: ImportWarning: __package__ != __spec__.parent
#   class ToolOutput(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/prompts/prompt_selector.py:9: ImportWarning: __package__ != __spec__.parent
#   class PromptSelector(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/llm_predictor/base.py:55: ImportWarning: __package__ != __spec__.parent
#   class LLMPredictor(BaseLLMPredictor):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/text_splitter/code_splitter.py:14: ImportWarning: __package__ != __spec__.parent
#   class CodeSplitter(TextSplitter):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/text_splitter/sentence_splitter.py:29: ImportWarning: __package__ != __spec__.parent
#   class SentenceSplitter(MetadataAwareTextSplitter):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/text_splitter/token_splitter.py:19: ImportWarning: __package__ != __spec__.parent
#   class TokenTextSplitter(MetadataAwareTextSplitter):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/indices/prompt_helper.py:30: ImportWarning: __package__ != __spec__.parent
#   class PromptHelper(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/node_parser/extractors/metadata_extractors.py:35: ImportWarning: __package__ != __spec__.parent
#   class MetadataFeatureExtractor(BaseExtractor):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/node_parser/extractors/metadata_extractors.py:54: ImportWarning: __package__ != __spec__.parent
#   class MetadataExtractor(BaseExtractor):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/node_parser/extractors/metadata_extractors.py:139: ImportWarning: __package__ != __spec__.parent
#   class TitleExtractor(MetadataFeatureExtractor):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/node_parser/extractors/metadata_extractors.py:225: ImportWarning: __package__ != __spec__.parent
#   class KeywordExtractor(MetadataFeatureExtractor):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/node_parser/extractors/metadata_extractors.py:272: ImportWarning: __package__ != __spec__.parent
#   class QuestionsAnsweredExtractor(MetadataFeatureExtractor):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/node_parser/extractors/metadata_extractors.py:350: ImportWarning: __package__ != __spec__.parent
#   class SummaryExtractor(MetadataFeatureExtractor):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/node_parser/extractors/metadata_extractors.py:442: ImportWarning: __package__ != __spec__.parent
#   class EntityExtractor(MetadataFeatureExtractor):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/node_parser/simple.py:15: ImportWarning: __package__ != __spec__.parent
#   class SimpleNodeParser(NodeParser):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/node_parser/sentence_window.py:20: ImportWarning: __package__ != __spec__.parent
#   class SentenceWindowNodeParser(NodeParser):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/vector_stores/types.py:63: ImportWarning: __package__ != __spec__.parent
#   class ExactMatchFilter(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/vector_stores/types.py:75: ImportWarning: __package__ != __spec__.parent
#   class MetadataFilters(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/vector_stores/types.py:85: ImportWarning: __package__ != __spec__.parent
#   class VectorStoreQuerySpec(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/vector_stores/types.py:97: ImportWarning: __package__ != __spec__.parent
#   class MetadataInfo(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/vector_stores/types.py:108: ImportWarning: __package__ != __spec__.parent
#   class VectorStoreInfo(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/tools/query_plan.py:32: ImportWarning: __package__ != __spec__.parent
#   class QueryNode(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/tools/query_plan.py:54: ImportWarning: __package__ != __spec__.parent
#   class QueryPlan(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/indices/postprocessor/node.py:36: ImportWarning: __package__ != __spec__.parent
#   class KeywordNodePostprocessor(BasePydanticNodePostprocessor):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/indices/postprocessor/node.py:72: ImportWarning: __package__ != __spec__.parent
#   class SimilarityPostprocessor(BasePydanticNodePostprocessor):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/indices/postprocessor/node.py:147: ImportWarning: __package__ != __spec__.parent
#   class PrevNextNodePostprocessor(BasePydanticNodePostprocessor):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/indices/postprocessor/node.py:261: ImportWarning: __package__ != __spec__.parent
#   class AutoPrevNextNodePostprocessor(BasePydanticNodePostprocessor):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/indices/postprocessor/node_recency.py:43: ImportWarning: __package__ != __spec__.parent
#   class FixedRecencyPostprocessor(BasePydanticNodePostprocessor):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/indices/postprocessor/node_recency.py:103: ImportWarning: __package__ != __spec__.parent
#   class EmbeddingRecencyPostprocessor(BasePydanticNodePostprocessor):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/indices/postprocessor/node_recency.py:188: ImportWarning: __package__ != __spec__.parent
#   class TimeWeightedPostprocessor(BasePydanticNodePostprocessor):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/indices/postprocessor/pii.py:41: ImportWarning: __package__ != __spec__.parent
#   class PIINodePostprocessor(BasePydanticNodePostprocessor):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/indices/postprocessor/pii.py:98: ImportWarning: __package__ != __spec__.parent
#   class NERPIINodePostprocessor(BasePydanticNodePostprocessor):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/objects/table_node_mapping.py:11: ImportWarning: __package__ != __spec__.parent
#   class SQLTableSchema(BaseModel):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/langchain_helpers/memory_wrapper.py:33: ImportWarning: __package__ != __spec__.parent
#   class GPTIndexMemory(Memory):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/langchain_helpers/memory_wrapper.py:103: ImportWarning: __package__ != __spec__.parent
#   class GPTIndexChatMemory(BaseChatMemory):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/llm_predictor/mock.py:84: ImportWarning: __package__ != __spec__.parent
#   class MockLLMPredictor(BaseLLMPredictor):
# /home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/llm_predictor/vellum/predictor.py:19: ImportWarning: __package__ != __spec__.parent
#   class VellumPredictor(BaseLLMPredictor):

# %% [markdown]
# ### SimpleWebPageReader: Web scraper that turns HTML to text

# %%
from llama_index import download_loader

SimpleWebPageReader = download_loader("SimpleWebPageReader")

loader = SimpleWebPageReader()
documents = loader.load_data(urls=['https://weaviate.io/blog/llamaindex-and-weaviate'])

# %% [markdown]
# ### NotionPageReader: Loads documents from Notion

# %%
from llama_index import download_loader

NotionPageReader = download_loader('NotionPageReader')

integration_token = ("secret_key")
page_ids = ["40be241cac924a5aa887fa85e945dbf6"]
reader = NotionPageReader(integration_token=integration_token)
documents = reader.load_data(page_ids=page_ids)
# Out:
# /usr/lib/python3.10/re.py:274: ResourceWarning: unclosed file <_io.TextIOWrapper name='/home/andrei/.venv/streamlit/lib/python3.10/site-packages/llama_index/readers/llamahub_modules/web/simple_web/requirements.txt' mode='r' encoding='UTF-8'>
#   return pattern.translate(_special_chars_map)
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 8
#       6 page_ids = ["40be241cac924a5aa887fa85e945dbf6"]
#       7 reader = NotionPageReader(integration_token=integration_token)
# ----> 8 documents = reader.load_data(page_ids=page_ids)
#
# File ~/.venv/streamlit/lib/python3.10/site-packages/llama_index/readers/llamahub_modules/notion/base.py:171, in NotionPageReader.load_data(self, page_ids, database_id)
#     169 else:
#     170     for page_id in page_ids:
# --> 171         page_text = self.read_page(page_id)
#     172         docs.append(Document(text=page_text, extra_info={"page_id": page_id}))
#     174 return docs
#
# File ~/.venv/streamlit/lib/python3.10/site-packages/llama_index/readers/llamahub_modules/notion/base.py:91, in NotionPageReader.read_page(self, page_id)
#      89 def read_page(self, page_id: str) -> str:
#      90     """Read a page."""
# ---> 91     return self._read_block(page_id)
#
# File ~/.venv/streamlit/lib/python3.10/site-packages/llama_index/readers/llamahub_modules/notion/base.py:56, in NotionPageReader._read_block(self, block_id, num_tabs)
#      51 res = requests.request(
#      52     "GET", block_url, headers=self.headers, json=query_dict
#      53 )
#      54 data = res.json()
# ---> 56 for result in data["results"]:
#      57     result_type = result["type"]
#      58     result_obj = result[result_type]
#
# KeyError: 'results'

# %% [markdown]
# ### Creating Nodes

# %%
from llama_index.node_parser import SimpleNodeParser

parser = SimpleNodeParser.from_defaults()
nodes = parser.get_nodes_from_documents(blogs)

# %% [markdown]
# ### Nodes to Weaviate

# %%
from llama_index.vector_stores import WeaviateVectorStore
from llama_index import VectorStoreIndex, StorageContext
from llama_index.storage.storage_context import StorageContext
import os

#os.environ["OPENAI_API_KEY"] = "sk-key"

# construct vector store
vector_store = WeaviateVectorStore(weaviate_client = client, index_name="BlogPost", text_key="content")

# setting up the storage for the embeddings
storage_context = StorageContext.from_defaults(vector_store = vector_store)

# set up the index
index = VectorStoreIndex.from_documents(nodes, storage_context = storage_context)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 15
#      12 storage_context = StorageContext.from_defaults(vector_store = vector_store)
#      14 # set up the index
# ---> 15 index = VectorStoreIndex.from_documents(nodes, storage_context = storage_context)
#
# File ~/.venv/streamlit/lib/python3.10/site-packages/llama_index/indices/base.py:97, in BaseIndex.from_documents(cls, documents, storage_context, service_context, show_progress, **kwargs)
#      95 with service_context.callback_manager.as_trace("index_construction"):
#      96     for doc in documents:
# ---> 97         docstore.set_document_hash(doc.get_doc_id(), doc.hash)
#      98     nodes = service_context.node_parser.get_nodes_from_documents(
#      99         documents, show_progress=show_progress
#     100     )
#     102     return cls(
#     103         nodes=nodes,
#     104         storage_context=storage_context,
#    (...)
#     107         **kwargs,
#     108     )
#
# AttributeError: 'TextNode' object has no attribute 'get_doc_id'

# %% [markdown]
# ### Query in LlamaIndex

# %%
query_engine = index.as_query_engine()
response = query_engine.query("What is the intersection between LLMs and search?")
print(response)

# %% [markdown]
# ## Connecting Weaviate Instance to LlamaIndex

# %%
import weaviate
from llama_index.readers.weaviate.reader import WeaviateReader

# WCS
resource_owner_config = weaviate.AuthClientPassword(
  username = "erika@weaviate.io", 
  password = "<password>"
)

# initialize reader
reader = WeaviateReader("https://llamaindex-episode1-samtusdu.weaviate.network", auth_client_secret=resource_owner_config)


documents = reader.load_data(
    class_name="BlogPost", 
    properties=["content"], 
    separate_documents=True
)


# localhost
# reader = WeaviateReader("http://localhost:8080")

# documents = reader.load_data(
#     class_name="BlogPost", 
#     properties=["content"], 
#     separate_documents=True
# )

# %% [markdown]
# ### Querying the existing class

# %%
from llama_index import ListIndex
import os

client = weaviate.Client(url="https://llamaindex-episode1-samtusdu.weaviate.network")

reader = WeaviateReader("https://llamaindex-episode1-samtusdu.weaviate.network")

query = """
{
  Get {
    BlogPost (
      bm25: {
        query: "What is ref2vec"
        properties: ["content"]
      },
      limit: 2
    ) {
      content
    }
  }
}
"""

documents = reader.load_data(graphql_query=query, separate_documents=True)

index = ListIndex.from_documents(documents)


query_engine = index.as_query_engine(response_mode="compact")
response = query_engine.query("what is ref2vec")
print(response)
